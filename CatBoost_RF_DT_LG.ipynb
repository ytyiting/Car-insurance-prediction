# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
import category_encoders as ce  # Leave-one-out, CatBoost, Heimert coding
from sklearn.preprocessing import StandardScaler  # label encoder, 標準化
from sklearn.cluster import DBSCAN  # outlier detection
from sklearn.model_selection import train_test_split, GridSearchCV  # split data into train data & test data

import warnings
warnings.filterwarnings('ignore')
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['figure.titlesize'] = 16
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['legend.fontsize'] = 10

# %%
#基本不更動raw_data, 之後都用df操作

# %%
raw_data = pd.read_csv('Car_Insurance_Claim.csv').drop(['ID'], axis=1)
display(raw_data.head())
print('The dimension of train dataset: ', raw_data.shape)
raw_data['OUTCOME'].value_counts()
# Out:
#      AGE  GENDER      RACE DRIVING_EXPERIENCE    EDUCATION         INCOME  \
# 0    65+  female  majority               0-9y  high school    upper class
# 1  16-25    male  majority               0-9y         none        poverty
# 2  16-25  female  majority               0-9y  high school  working class
# 3  16-25    male  majority               0-9y   university  working class
# 4  26-39    male  majority             10-19y         none  working class
#
#    CREDIT_SCORE  VEHICLE_OWNERSHIP VEHICLE_YEAR  MARRIED  CHILDREN  \
# 0      0.629027                1.0   after 2015      0.0       1.0
# 1      0.357757                0.0  before 2015      0.0       0.0
# 2      0.493146                1.0  before 2015      0.0       0.0
# 3      0.206013                1.0  before 2015      0.0       1.0
# 4      0.388366                1.0  before 2015      0.0       0.0
#
#    POSTAL_CODE  ANNUAL_MILEAGE VEHICLE_TYPE  SPEEDING_VIOLATIONS  DUIS  \
# 0        10238         12000.0        sedan                    0     0
# 1        10238         16000.0        sedan                    0     0
# 2        10238         11000.0        sedan                    0     0
# 3        32765         11000.0        sedan                    0     0
# 4        32765         12000.0        sedan                    2     0
#
#    PAST_ACCIDENTS  OUTCOME
# 0               0      0.0
# 1               0      1.0
# 2               0      0.0
# 3               0      0.0
# 4               1      1.0
# The dimension of train dataset:  (10000, 18)
# 0.0    6867
# 1.0    3133
# Name: OUTCOME, dtype: int64

# %% [markdown]
# <div style="background-color:#D9D9D9;"><font size="5"> -嚴重的<b> data imbalanced-</b></font></div>約1:15

# %%
raw_data.describe()
# Out:
#        CREDIT_SCORE  VEHICLE_OWNERSHIP       MARRIED      CHILDREN  \
# count   9018.000000       10000.000000  10000.000000  10000.000000
# mean       0.515813           0.697000      0.498200      0.688800
# std        0.137688           0.459578      0.500022      0.463008
# min        0.053358           0.000000      0.000000      0.000000
# 25%        0.417191           0.000000      0.000000      0.000000
# 50%        0.525033           1.000000      0.000000      1.000000
# 75%        0.618312           1.000000      1.000000      1.000000
# max        0.960819           1.000000      1.000000      1.000000
#
#         POSTAL_CODE  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS         DUIS  \
# count  10000.000000     9043.000000         10000.000000  10000.00000
# mean   19864.548400    11697.003207             1.482900      0.23920
# std    18915.613855     2818.434528             2.241966      0.55499
# min    10238.000000     2000.000000             0.000000      0.00000
# 25%    10238.000000    10000.000000             0.000000      0.00000
# 50%    10238.000000    12000.000000             0.000000      0.00000
# 75%    32765.000000    14000.000000             2.000000      0.00000
# max    92101.000000    22000.000000            22.000000      6.00000
#
#        PAST_ACCIDENTS       OUTCOME
# count    10000.000000  10000.000000
# mean         1.056300      0.313300
# std          1.652454      0.463858
# min          0.000000      0.000000
# 25%          0.000000      0.000000
# 50%          0.000000      0.000000
# 75%          2.000000      1.000000
# max         15.000000      1.000000

# %%
percentage_result = raw_data.isnull().sum()/raw_data.shape[0]
percentage_result = pd.DataFrame({"missing": percentage_result}) #"columns": percentage_result.keys(), 
percentage_result.sort_values(by='missing', ascending=False).head()
# Out:
#                 missing
# CREDIT_SCORE     0.0982
# ANNUAL_MILEAGE   0.0957
# AGE              0.0000
# CHILDREN         0.0000
# PAST_ACCIDENTS   0.0000

# %%
raw_data.fillna(raw_data.mean(),inplace=True)
percentage_result = raw_data.isnull().sum()/raw_data.shape[0]
percentage_result = pd.DataFrame({"missing": percentage_result}) #"columns": percentage_result.keys(), 
percentage_result.sort_values(by='missing', ascending=False).head()
# Out:
#                      missing
# AGE                      0.0
# GENDER                   0.0
# PAST_ACCIDENTS           0.0
# DUIS                     0.0
# SPEEDING_VIOLATIONS      0.0

# %% [markdown]
# 可以知道<b> 沒有資料缺失</b>，接著處理類別變數<br>
# 發現眾多欄位包含Yes/No, 將其與其他類別變數分開處理<br>
# 處理順序：先編碼(encode)，再分割訓練測試集(split)，再標準化(standardize)
# - https://jamesmccaffrey-wordpress-com.translate.goog/2020/05/27/should-you-normalize-and-encode-data-before-train-test-splitting-or-after-splitting/?_x_tr_sl=auto&_x_tr_tl=zh-CN&_x_tr_hl=zh-CN

# %% [markdown]
# - 類別變數：
#     - 其中make為隱藏的車子製造商1~5, model為車子名稱(兩萬多種),
#     - 'area_cluster', 'make', 'segment', 'model', 'fuel_type', 'max_torque', 'max_power', 'engine_type', 'rear_brakes_type', 'transmission_type', 'steering_type'
# - Y/N變數：
#     - 'is_esc', 'is_adjustable_steering', 'is_tpms', 'is_parking_sensors', 'is_parking_camera', 'is_front_fog_lights', 'is_rear_window_wiper', 'is_rear_window_washer', 'is_rear_window_defogger', 'is_brake_assist', 'is_power_door_locks', 'is_central_locking', 'is_power_steering', 'is_driver_seat_height_adjustable', 'is_day_night_rear_view_mirror', 'is_ecw', 'is_speed_alert'

# %%
# lists
var_of_category = ['AGE', 'GENDER', 'RACE', 'DRIVING_EXPERIENCE', 'EDUCATION', 'INCOME', 'VEHICLE_YEAR', 'VEHICLE_TYPE']
# var_of_yn = ['is_esc', 'is_adjustable_steering', 'is_tpms', 'is_parking_sensors', 'is_parking_camera', 'is_front_fog_lights', 'is_rear_window_wiper', 'is_rear_window_washer', 'is_rear_window_defogger', 'is_brake_assist', 'is_power_door_locks', 'is_central_locking', 'is_power_steering', 'is_driver_seat_height_adjustable', 'is_day_night_rear_view_mirror', 'is_ecw', 'is_speed_alert']

# %% [markdown]
# 首先把Yes轉為1, No轉為0

# %%
df = raw_data.copy()

# %% [markdown]
# category encoding，採用target encoding中的catboost<br>
# https://zhuanlan.zhihu.com/p/560004588<br>
# https://zhuanlan.zhihu.com/p/40231966

# %%
import category_encoders as ce
cbe_encoder = ce.cat_boost.CatBoostEncoder()
train_cbe = cbe_encoder.fit_transform(df[var_of_category], df['OUTCOME'])
for idx in var_of_category:
    df[idx] = train_cbe[idx].values
df
# Out:
#            AGE    GENDER      RACE  DRIVING_EXPERIENCE  EDUCATION    INCOME  \
# 0     0.313300  0.313300  0.313300            0.313300   0.313300  0.313300
# 1     0.313300  0.313300  0.156650            0.156650   0.313300  0.313300
# 2     0.656650  0.156650  0.437767            0.437767   0.156650  0.313300
# 3     0.437767  0.656650  0.328325            0.328325   0.313300  0.156650
# 4     0.313300  0.437767  0.262660            0.313300   0.656650  0.104433
# ...        ...       ...       ...                 ...        ...       ...
# 9995  0.337141  0.263693  0.312091            0.238494   0.225640  0.133605
# 9996  0.337030  0.263641  0.312056            0.238421   0.471951  0.277170
# 9997  0.336920  0.363189  0.312021            0.628312   0.323223  0.277041
# 9998  0.336810  0.263588  0.311987            0.238349   0.323145  0.653425
# 9999  0.337027  0.263735  0.312063            0.628134   0.471704  0.453454
#
#       CREDIT_SCORE  VEHICLE_OWNERSHIP  VEHICLE_YEAR  MARRIED  CHILDREN  \
# 0         0.629027                1.0      0.313300      0.0       1.0
# 1         0.357757                0.0      0.313300      0.0       0.0
# 2         0.493146                1.0      0.656650      0.0       0.0
# 3         0.206013                1.0      0.437767      0.0       1.0
# 4         0.388366                1.0      0.328325      0.0       0.0
# ...            ...                ...           ...      ...       ...
# 9995      0.582787                1.0      0.403405      0.0       0.0
# 9996      0.522231                1.0      0.106599      0.0       1.0
# 9997      0.470940                1.0      0.403347      0.0       1.0
# 9998      0.364185                0.0      0.403289      0.0       1.0
# 9999      0.435225                1.0      0.403375      1.0       1.0
#
#       POSTAL_CODE  ANNUAL_MILEAGE  VEHICLE_TYPE  SPEEDING_VIOLATIONS  DUIS  \
# 0           10238    12000.000000      0.313300                    0     0
# 1           10238    16000.000000      0.156650                    0     0
# 2           10238    11000.000000      0.437767                    0     0
# 3           32765    11000.000000      0.328325                    0     0
# 4           32765    12000.000000      0.262660                    2     0
# ...           ...             ...           ...                  ...   ...
# 9995        10238    16000.000000      0.312776                    0     0
# 9996        32765    11697.003207      0.312743                    1     0
# 9997        10238    14000.000000      0.312710                    0     0
# 9998        10238    13000.000000      0.312677                    2     0
# 9999        10238    13000.000000      0.312749                    0     0
#
#       PAST_ACCIDENTS  OUTCOME
# 0                  0      0.0
# 1                  0      1.0
# 2                  0      0.0
# 3                  0      0.0
# 4                  1      1.0
# ...              ...      ...
# 9995               1      0.0
# 9996               0      0.0
# 9997               0      0.0
# 9998               1      1.0
# 9999               0      0.0
#
# [10000 rows x 18 columns]

# %%
target = [i for i in df.columns]
plt.figure(figsize=(10,45))
for n,column in enumerate(target):
    plot=plt.subplot(22,2,n+1)
    sns.distplot(df[column],color='green')
    plt.title(f'{column.title()}',weight='bold')
    plt.tight_layout()

# %%
sns.set(font_scale=0.7)
heatmap = sns.heatmap(round(df.corr(), 2),
                        annot=False,
                        cmap="vlag",
                        vmax=1,
                        vmin=-1)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize': 18}, pad=16)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
from yellowbrick.features import RadViz


visualizer = RadViz(classes=["is claim","not claim"],
                    features=list(df.columns[:-1]), size=(720, 720))
visualizer.fit(df.iloc[:,:-1].values, df['OUTCOME'].values)
visualizer.transform(df[:-1].values)
visualizer.poof()
# Out:
# <AxesSubplot: title={'center': 'RadViz for 17 Features'}>

# %% [markdown]
# 上圖看起來標籤的分類沒有很明確，故不期待結果準確區分OUTCOME，本身是具有偏大難度<br>

# %% [markdown]
# 之後嘗試接著處理資料不平衡<br><br>
# 為了避免受到噪音干擾，同時採用`ENN`(Edited Nearest Neighbor)和`Borderline Smote`進行採樣<br>
# - ENN可以改為Tomek Link Removal，Borderline Smote可以改為單純Smote<br>
# - 也可以試著採用集成方法Ensemble(BalanceCascade)
# - http://www.17bigdata.com/聊聊样本采样技术/
# ----
# 採樣前得先對數據標準化，標準化之前先分好訓練集&測試集

# %%
X = df.iloc[:, :-1]
y = df['OUTCOME']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
standard_scaler = StandardScaler()
X_train = pd.DataFrame(standard_scaler.fit_transform(X_train), columns=X_train.columns) #先fit
X_test = pd.DataFrame(standard_scaler.transform(X_test), columns=X_test.columns) #再transform
X_train
# Out:
#            AGE    GENDER      RACE  DRIVING_EXPERIENCE  EDUCATION    INCOME  \
# 0    -0.924044 -1.066367 -0.233246           -1.138878   0.087149 -0.900274
# 1     0.069008  0.704061 -0.669936            1.285899   1.793799  1.767215
# 2     0.070896 -0.977978 -1.880052            1.255789  -0.897356 -0.221616
# 3    -0.691115 -1.008799 -0.041609           -0.283032   0.062556 -0.867563
# 4    -0.691580  1.035805 -0.083561            1.268646  -0.903305 -0.171144
# ...        ...       ...       ...                 ...        ...       ...
# 7995 -0.924882  1.097259 -0.129993           -1.148506   0.097496 -0.874525
# 7996  1.780714  1.128556 -0.172320            1.290412  -0.945007  0.665540
# 7997 -0.924288 -1.067538 -0.179116           -1.144416  -0.950017 -0.882410
# 7998 -0.848624  0.545443 -1.340030           -1.083527  -1.126567 -1.039065
# 7999  1.788438  1.088066 -0.104860            1.266778   0.087498  0.646325
#
#       CREDIT_SCORE  VEHICLE_OWNERSHIP  VEHICLE_YEAR   MARRIED  CHILDREN  \
# 0         0.231601           0.661480     -1.526241  0.997004  0.677143
# 1        -1.177864          -1.511761      0.564189  0.997004  0.677143
# 2         0.158058           0.661480      0.549875  0.997004 -1.476792
# 3         0.747094           0.661480     -1.507686  0.997004 -1.476792
# 4        -0.314774           0.661480      0.644004 -1.003005 -1.476792
# ...            ...                ...           ...       ...       ...
# 7995      1.367429           0.661480      0.662910  0.997004  0.677143
# 7996      0.051440           0.661480     -1.541378 -1.003005 -1.476792
# 7997      0.850495           0.661480     -1.543458  0.997004  0.677143
# 7998      1.732647           0.661480     -1.632595  0.997004  0.677143
# 7999     -1.322063          -1.511761      0.647126  0.997004  0.677143
#
#       POSTAL_CODE  ANNUAL_MILEAGE  VEHICLE_TYPE  SPEEDING_VIOLATIONS  \
# 0       -0.511636       -1.380447     -0.130468             1.111686
# 1       -0.511636       -1.006844     -0.517924            -0.661338
# 2       -0.511636        0.113963     -0.697216            -0.661338
# 3        0.685773       -1.006844      0.025767             0.668430
# 4        0.685773        0.487566     -0.039890            -0.661338
# ...           ...             ...           ...                  ...
# 7995    -0.511636        0.861168      0.023362             0.668430
# 7996    -0.511636       -0.259639      0.143387            -0.661338
# 7997    -0.511636        0.000763     -0.001979            -0.661338
# 7998    -0.511636       -1.380447     -0.436923            -0.218082
# 7999    -0.511636       -0.633242     -0.053891            -0.661338
#
#           DUIS  PAST_ACCIDENTS
# 0    -0.433018        2.940435
# 1    -0.433018       -0.642457
# 2    -0.433018       -0.642457
# 3    -0.433018       -0.642457
# 4    -0.433018       -0.642457
# ...        ...             ...
# 7995  1.346202        1.148989
# 7996 -0.433018       -0.642457
# 7997 -0.433018        0.551840
# 7998 -0.433018        2.343286
# 7999 -0.433018       -0.642457
#
# [8000 rows x 17 columns]

# %% [markdown]
# #### Base line performance

# %%
from collections import Counter
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn import metrics

# %%
def fit_result(model, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)
    predicted_y = model.predict(X_test)
    true_y = y_test
    
    print("對於主要目標 標籤為1的預測")
    print(f"Precision：{metrics.precision_score(true_y, predicted_y)}, \
            Recall：{metrics.recall_score(true_y, predicted_y)},\n \
       Accuracy：{metrics.accuracy_score(true_y, predicted_y)}, \
       AUC：{metrics.roc_auc_score(true_y, model.predict_proba(X_test)[:,1])}, \
       f1-score：{metrics.f1_score(true_y, predicted_y)}")
    cm = confusion_matrix(true_y, predicted_y)
    print(cm) 
    print(metrics.classification_report(true_y, predicted_y))
    
    #此處-1是先的label容易搞混，但我們就照平常的方法來不管此例是-1還是1
    fig, ax = plt.subplots(figsize=(5, 5))
    plot_confusion_matrix(model, X_test, y_test,  cmap=plt.cm.Blues, colorbar=False, ax=ax)
    plt.show()
    
    #已驗算過
    print('The TP rate is: {0:4.2}'.format(float(cm[0][0])/np.sum(cm[0])))
    print('The TN rate is: {0:4.2}'.format(float(cm[1][1])/np.sum(cm[1])))
    print('The FN rate is: {0:4.2}'.format(1- float(cm[0][0])/np.sum(cm[0]))) #FN = 1-TP
    print('The FP rate is: {0:4.2}'.format(1- float(cm[1][1])/np.sum(cm[1]))) #FP = 1-TN

# %%
model = DecisionTreeClassifier(splitter='random')
fit_result(model, X_train, y_train, X_test, y_test)
# Out:
# 對於主要目標 標籤為1的預測
# Precision：0.6666666666666666,             Recall：0.6382306477093207,
#         Accuracy：0.7845,        AUC：0.745230905420132,        f1-score：0.652138821630347
# [[1165  202]
#  [ 229  404]]
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.85      0.84      1367
#          1.0       0.67      0.64      0.65       633
#
#     accuracy                           0.78      2000
#    macro avg       0.75      0.75      0.75      2000
# weighted avg       0.78      0.78      0.78      2000
# The TP rate is: 0.85
# The TN rate is: 0.64
# The FN rate is: 0.15
# The FP rate is: 0.36

# %%
from collections import Counter
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# %% [markdown]
# ### CrossCV測試樣本比例
# #### *****之後記得把kind_sel的模式改看看，也可以試試一般的ENN*****
# https://blog.csdn.net/mathlxj/article/details/89645321
# (mode只刪了626筆，另一個能刪除一萬多)

# %%
from imblearn.under_sampling import RepeatedEditedNearestNeighbours
from imblearn.under_sampling import EditedNearestNeighbours
from imblearn.over_sampling import BorderlineSMOTE
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline


model = DecisionTreeClassifier(splitter='random')
print("before data balancing：",Counter(y_train))
print()

# for i in np.linspace(0.2, 1, 9):
#     for j in range(3, 9, 2):   
#         renn = RepeatedEditedNearestNeighbours()#kind_sel='mode'
#         BDsmote = BorderlineSMOTE(m_neighbors=j, sampling_strategy=i)
#         steps = [('under(renn)', renn), ('over(BDsmote)', BDsmote)]
#         pipeline = Pipeline(steps=steps)
#         X_cv, y_cv = pipeline.fit_resample(X_train, y_train)

#         #重複兩次 5-fold來評分
#         cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=2, random_state=42)
#         scores = cross_val_score(model, X_cv, y_cv, scoring='f1_macro', cv=cv) #n_jobs為一次運行多少processor
#         print(f'ratio={i}, m={j}, Mean f1_macro: %.3f' % np.mean(scores))
#     print("after data balancing:",Counter(y_cv))
#     print()
#     #print("after data balancing:",Counter(y_cv))
# Out:
# before data balancing： Counter({0.0: 5500, 1.0: 2500})

# %% [markdown]
# 發現在樣本數為1:1，BorderlineSMOTE m=3的情況下會得到較好的f1_macro值<br>
# <b>注意:</b> 此結果是基於兩label的資料分布有改變後的結果，才會有此好的結果在f1_macro

# %% [markdown]
# 正式將訓練資料重新取樣 -> X_train_sm, y_train_sm, X_test, y_test<br>
# 再看一次結果分佈，發現預測為`1`的比例提高了，但是是以數量換得的recall

# %%
renn = EditedNearestNeighbours()#kind_sel='mode'
BDsmote = BorderlineSMOTE(m_neighbors=3, sampling_strategy=1.0)
steps = [('under(renn)', renn), ('over(BDsmote)', BDsmote)]
pipeline = Pipeline(steps=steps)
X_train_sm, y_train_sm = pipeline.fit_resample(X_train, y_train)

model = DecisionTreeClassifier(splitter='random')
fit_result(model, X_train_sm, y_train_sm, X_test, y_test)
# Out:
# 對於主要目標 標籤為1的預測
# Precision：0.6020293122886133,             Recall：0.8436018957345972,
#         Accuracy：0.774,        AUC：0.7926860978307222,        f1-score：0.7026315789473685
# [[1014  353]
#  [  99  534]]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.74      0.82      1367
#          1.0       0.60      0.84      0.70       633
#
#     accuracy                           0.77      2000
#    macro avg       0.76      0.79      0.76      2000
# weighted avg       0.81      0.77      0.78      2000
# The TP rate is: 0.74
# The TN rate is: 0.84
# The FN rate is: 0.26
# The FP rate is: 0.16

# %%
from yellowbrick.features import RadViz


visualizer = RadViz(classes=["is claim","not claim"],
                    features=list(X_train_sm.columns), size=(720, 720))
visualizer.fit(X_train_sm.values, y_train_sm.values)
visualizer.transform(X_train_sm.values)
visualizer.poof()
# Out:
# <AxesSubplot: title={'center': 'RadViz for 17 Features'}>

# %% [markdown]
# #### 接著進行特徵挑選

# %% [markdown]
# <br>單一特徵排名 / 皮爾森相關係數<br>
# 特徵的一維排名利用的是一次只考慮單一特徵的排名算法，可以顯示每個特徵的相對排名

# %%
from yellowbrick.features import rank1d, rank2d

_, axes = plt.subplots(ncols=2, figsize=(30, 10))

rank1d(X_train_sm, ax=axes[0], show=False)
rank2d(X_train_sm, ax=axes[1], show=False)
plt.show()
sns.set(font_scale=1.2)

# %%
from collinearity import SelectNonCollinear  #消除共線性 這個方法可以使用在監督學習以及非監督式學習

# %%
def UNIP(x, y, threshold):
    selector = SelectNonCollinear(threshold)

    selector.fit(x.values, y.values)
    corr = selector.transform(x.values)

    mask = selector.get_support()

    new_feature = []
    for i in range(len(mask)):
        if mask[i] == True:
            new_feature.append(x.columns[i])

    display(new_feature)

    sns.set(font_scale=0.7)
    heatmap = sns.heatmap(round(x[new_feature].corr(), 2),
                          annot=False,
                          cmap="vlag",
                          vmax=1,
                          vmin=-1)
    heatmap.set_title('Correlation Heatmap', fontdict={'fontsize': 18}, pad=16)

    return new_feature

# %%
HT = UNIP(X_train_sm, y_train_sm, threshold=0.80) #印出選擇後特徵
print(f'After removing {X_train_sm.shape[1]-len(HT)} features, there are {len(HT)} features left.')
# Out:
# ['AGE',
#  'GENDER',
#  'RACE',
#  'DRIVING_EXPERIENCE',
#  'EDUCATION',
#  'INCOME',
#  'CREDIT_SCORE',
#  'VEHICLE_OWNERSHIP',
#  'VEHICLE_YEAR',
#  'MARRIED',
#  'CHILDREN',
#  'POSTAL_CODE',
#  'ANNUAL_MILEAGE',
#  'VEHICLE_TYPE',
#  'SPEEDING_VIOLATIONS',
#  'DUIS',
#  'PAST_ACCIDENTS']
# After removing 0 features, there are 17 features left.

# %%
X_train_HT = X_train_sm[HT]
X_test_HT = X_test[HT]

# %% [markdown]
# #### 接著用Lasso進行壓縮

# %%
from sklearn.linear_model import Lasso
model = Lasso(alpha=0.005, tol=1e-5)#alpha=0.015, tol=1e-1
model.fit(X_train_HT, y_train_sm)
predicted_y = model.predict(X_test_HT)
#model.coef_

# %%
importance = zip(model.coef_, X_train_HT.columns)
imp = list(importance)
imp.sort(key=lambda x: abs(x[0]), reverse=True) 
x_pos = np.arange(len(imp)) 
score = list(map(lambda x: x[0], imp))
name = list(map(lambda x: x[1], imp))

plt.bar(x_pos, score,align='center')
plt.xticks(x_pos, name, rotation = 85) 
plt.ylabel('Feature Importance')
plt.show()
print('the last few features is almost 0, we can discard them.')
# Out:
# the last few features is almost 0, we can discard them.

# %%
imp_feature = [x[1] for x in imp if abs(x[0])>0]
print(f"there are {len(imp_feature)} features left.")
# Out:
# there are 15 features left.

# %%
X_train_final = X_train_HT[imp_feature]
X_test_final = X_test_HT[imp_feature]
y_train_final = y_train_sm
y_test_final = y_test
X_train_final
# Out:
#       DRIVING_EXPERIENCE  VEHICLE_YEAR  VEHICLE_OWNERSHIP  POSTAL_CODE  \
# 0              -1.138878     -1.526241           0.661480    -0.511636
# 1               1.255789      0.549875           0.661480    -0.511636
# 2              -0.283032     -1.507686           0.661480     0.685773
# 3              -0.287644      0.652179           0.661480    -0.511636
# 4              -0.281967      0.643959           0.661480     0.685773
# ...                  ...           ...                ...          ...
# 7475            1.294618     -1.538271           0.661480    -0.091852
# 7476           -1.088677     -1.567802           0.661480     0.071946
# 7477           -0.276206      0.665925           0.661480     0.226022
# 7478           -0.478129      0.702425           0.578035    -0.511636
# 7479           -0.535329     -1.646709          -1.511761     0.685773
#
#         GENDER  PAST_ACCIDENTS   MARRIED  CHILDREN    INCOME  ANNUAL_MILEAGE  \
# 0    -1.066367        2.940435  0.997004  0.677143 -0.900274       -1.380447
# 1    -0.977978       -0.642457  0.997004 -1.476792 -0.221616        0.113963
# 2    -1.008799       -0.642457  0.997004 -1.476792 -0.867563       -1.006844
# 3    -0.997351       -0.045309  0.997004 -1.476792  0.652674        0.487566
# 4    -1.060039       -0.642457 -1.003005  0.677143  0.686483       -0.633242
# ...        ...             ...       ...       ...       ...             ...
# 7475  0.987660       -0.642457 -0.441649  0.677143  0.420962        0.054945
# 7476 -0.921291       -0.136886  0.997004  0.677143 -0.785877       -0.518652
# 7477  1.112026       -0.195198  0.997004  0.677143 -0.886473        0.000763
# 7478  0.156947       -0.045309  0.997004 -1.476792  0.963355       -0.633242
# 7479 -0.407870       -0.089095 -1.003005  0.677143 -0.243976       -0.073121
#
#       VEHICLE_TYPE      RACE      DUIS  EDUCATION  CREDIT_SCORE
# 0        -0.130468 -0.233246 -0.433018   0.087149      0.231601
# 1        -0.697216 -1.880052 -0.433018  -0.897356      0.158058
# 2         0.025767 -0.041609 -0.433018   0.062556      0.747094
# 3         0.033651 -0.076759 -0.433018   0.057660     -1.430277
# 4        -0.137445 -0.238720 -0.433018   1.645003     -0.290019
# ...            ...       ...       ...        ...           ...
# 7475      0.021418  0.023778 -0.433018  -0.965086      0.567590
# 7476     -0.479758 -0.536492 -0.433018  -0.956278      0.658393
# 7477      0.148634  0.087732  0.013582  -0.933421      0.866670
# 7478     -0.608594  0.025645 -0.433018   0.376418     -0.830171
# 7479     -1.070997 -0.569832 -0.433018   1.702990     -0.713214
#
# [7480 rows x 15 columns]

# %% [markdown]
# ### 特徵挑選完成，開始訓練模型

# %%
model = DecisionTreeClassifier(splitter='random')
fit_result(model, X_train_final, y_train_final, X_test_final, y_test_final)
# Out:
# 對於主要目標 標籤為1的預測
# Precision：0.6036036036036037,             Recall：0.8467614533965245,
#         Accuracy：0.7755,        AUC：0.7946316411093816,        f1-score：0.7047994740302433
# [[1015  352]
#  [  97  536]]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.74      0.82      1367
#          1.0       0.60      0.85      0.70       633
#
#     accuracy                           0.78      2000
#    macro avg       0.76      0.79      0.76      2000
# weighted avg       0.81      0.78      0.78      2000
# The TP rate is: 0.74
# The TN rate is: 0.85
# The FN rate is: 0.26
# The FP rate is: 0.15

# %% [markdown]
# ### 使用CrossCV測試各種模型參數
# <br>使用時長很大，小心執行。

# %%
#crossCV挑參數
#https://blog.csdn.net/weixin_41712499/article/details/82882542
#https://ithelp.ithome.com.tw/articles/10267379?sc=iThomeR
# n_estimators: 森林中樹木的數量，預設=100。
# max_features: 劃分時考慮的最大特徵數，預設auto。
# criterion: 亂度的評估標準，gini/entropy。預設為gini。
# max_depth: 樹的最大深度。
# splitter: 特徵劃分點選擇標準，best/random。預設為best。
# random_state: 亂數種子，確保每次訓練結果都一樣，splitter=random 才有用。
# min_samples_split: 至少有多少資料才能再分
# min_samples_leaf: 分完至少有多少資料才能分
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RandomizedSearchCV

model = RandomForestClassifier(n_estimators=100, random_state= 42)

n_estimators = [int(x) for x in np.linspace(start=100, stop=2000, num=10)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(5,15, num=8)]
max_depth.append(None)
min_samples_split = [2, 3, 7, 13, 20, 50, 100]
min_samples_leaf = [5, 10, 20, 40, 80]
bootstrap = [True, False]

random_grid = {'n_estimators': n_estimators, 'max_features': max_features,
               'max_depth': max_depth, 'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf, 'bootstrap': bootstrap}
random_grid
# Out:
# {'n_estimators': [100, 311, 522, 733, 944, 1155, 1366, 1577, 1788, 2000],
#  'max_features': ['auto', 'sqrt'],
#  'max_depth': [5, 6, 7, 9, 10, 12, 13, 15, None],
#  'min_samples_split': [2, 3, 7, 13, 20, 50, 100],
#  'min_samples_leaf': [5, 10, 20, 40, 80],
#  'bootstrap': [True, False]}

# %%
rdforest = RandomForestClassifier(random_state=42)
rf_random = RandomizedSearchCV(estimator = rdforest, param_distributions=random_grid,
                              n_iter=20, cv=3, verbose=3, scoring='f1_macro', random_state=42)#, n_jobs=-1

rf_random.fit(X_train_final,y_train_final)
rf_random.best_params_
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV 1/3] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=40, min_samples_split=100, n_estimators=100;, score=0.886 total time=   0.3s
# [CV 2/3] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=40, min_samples_split=100, n_estimators=100;, score=0.910 total time=   0.3s
# [CV 3/3] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=40, min_samples_split=100, n_estimators=100;, score=0.712 total time=   0.3s
# [CV 1/3] END bootstrap=True, max_depth=6, max_features=auto, min_samples_leaf=20, min_samples_split=7, n_estimators=100;, score=0.887 total time=   0.2s
# [CV 2/3] END bootstrap=True, max_depth=6, max_features=auto, min_samples_leaf=20, min_samples_split=7, n_estimators=100;, score=0.905 total time=   0.2s
# [CV 3/3] END bootstrap=True, max_depth=6, max_features=auto, min_samples_leaf=20, min_samples_split=7, n_estimators=100;, score=0.730 total time=   0.2s
# [CV 1/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=100;, score=0.898 total time=   0.2s
# [CV 2/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=100;, score=0.918 total time=   0.2s
# [CV 3/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=100;, score=0.753 total time=   0.2s
# [CV 1/3] END bootstrap=True, max_depth=15, max_features=auto, min_samples_leaf=80, min_samples_split=3, n_estimators=311;, score=0.884 total time=   0.7s
# [CV 2/3] END bootstrap=True, max_depth=15, max_features=auto, min_samples_leaf=80, min_samples_split=3, n_estimators=311;, score=0.904 total time=   0.8s
# [CV 3/3] END bootstrap=True, max_depth=15, max_features=auto, min_samples_leaf=80, min_samples_split=3, n_estimators=311;, score=0.696 total time=   0.7s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=944;, score=0.902 total time=   4.5s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=944;, score=0.920 total time=   4.5s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=944;, score=0.779 total time=   4.3s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=3, n_estimators=944;, score=0.913 total time=   4.9s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=3, n_estimators=944;, score=0.929 total time=   5.0s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=3, n_estimators=944;, score=0.834 total time=   4.7s
# [CV 1/3] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=944;, score=0.895 total time=   3.0s
# [CV 2/3] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=944;, score=0.915 total time=   2.9s
# [CV 3/3] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=944;, score=0.726 total time=   2.8s
# [CV 1/3] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=80, min_samples_split=13, n_estimators=1155;, score=0.885 total time=   3.0s
# [CV 2/3] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=80, min_samples_split=13, n_estimators=1155;, score=0.901 total time=   3.1s
# [CV 3/3] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=80, min_samples_split=13, n_estimators=1155;, score=0.698 total time=   3.0s
# [CV 1/3] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=1366;, score=0.882 total time=   3.6s
# [CV 2/3] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=1366;, score=0.900 total time=   3.6s
# [CV 3/3] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=1366;, score=0.706 total time=   3.5s
# [CV 1/3] END bootstrap=True, max_depth=13, max_features=auto, min_samples_leaf=40, min_samples_split=3, n_estimators=1366;, score=0.893 total time=   4.1s
# [CV 2/3] END bootstrap=True, max_depth=13, max_features=auto, min_samples_leaf=40, min_samples_split=3, n_estimators=1366;, score=0.913 total time=   4.1s
# [CV 3/3] END bootstrap=True, max_depth=13, max_features=auto, min_samples_leaf=40, min_samples_split=3, n_estimators=1366;, score=0.715 total time=   4.0s
# [CV 1/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=80, min_samples_split=20, n_estimators=1788;, score=0.886 total time=   4.8s
# [CV 2/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=80, min_samples_split=20, n_estimators=1788;, score=0.901 total time=   4.7s
# [CV 3/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=80, min_samples_split=20, n_estimators=1788;, score=0.696 total time=   4.7s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=1366;, score=0.912 total time=   7.2s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=1366;, score=0.929 total time=   7.2s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=1366;, score=0.834 total time=   6.9s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=auto, min_samples_leaf=20, min_samples_split=7, n_estimators=733;, score=0.907 total time=   3.6s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=auto, min_samples_leaf=20, min_samples_split=7, n_estimators=733;, score=0.925 total time=   3.6s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=auto, min_samples_leaf=20, min_samples_split=7, n_estimators=733;, score=0.788 total time=   3.4s
# [CV 1/3] END bootstrap=False, max_depth=13, max_features=sqrt, min_samples_leaf=40, min_samples_split=50, n_estimators=311;, score=0.897 total time=   1.3s
# [CV 2/3] END bootstrap=False, max_depth=13, max_features=sqrt, min_samples_leaf=40, min_samples_split=50, n_estimators=311;, score=0.918 total time=   1.3s
# [CV 3/3] END bootstrap=False, max_depth=13, max_features=sqrt, min_samples_leaf=40, min_samples_split=50, n_estimators=311;, score=0.743 total time=   1.3s
# [CV 1/3] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=40, min_samples_split=100, n_estimators=522;, score=0.894 total time=   2.1s
# [CV 2/3] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=40, min_samples_split=100, n_estimators=522;, score=0.912 total time=   2.1s
# [CV 3/3] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=40, min_samples_split=100, n_estimators=522;, score=0.722 total time=   2.0s
# [CV 1/3] END bootstrap=True, max_depth=7, max_features=auto, min_samples_leaf=80, min_samples_split=2, n_estimators=1155;, score=0.884 total time=   3.0s
# [CV 2/3] END bootstrap=True, max_depth=7, max_features=auto, min_samples_leaf=80, min_samples_split=2, n_estimators=1155;, score=0.900 total time=   3.1s
# [CV 3/3] END bootstrap=True, max_depth=7, max_features=auto, min_samples_leaf=80, min_samples_split=2, n_estimators=1155;, score=0.694 total time=   3.0s
# [CV 1/3] END bootstrap=True, max_depth=6, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=2000;, score=0.888 total time=   5.8s
# [CV 2/3] END bootstrap=True, max_depth=6, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=2000;, score=0.906 total time=   5.8s
# [CV 3/3] END bootstrap=True, max_depth=6, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=2000;, score=0.718 total time=   5.6s
# [CV 1/3] END bootstrap=False, max_depth=13, max_features=auto, min_samples_leaf=10, min_samples_split=3, n_estimators=733;, score=0.913 total time=   3.9s
# [CV 2/3] END bootstrap=False, max_depth=13, max_features=auto, min_samples_leaf=10, min_samples_split=3, n_estimators=733;, score=0.930 total time=   4.0s
# [CV 3/3] END bootstrap=False, max_depth=13, max_features=auto, min_samples_leaf=10, min_samples_split=3, n_estimators=733;, score=0.836 total time=   3.7s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=80, min_samples_split=3, n_estimators=2000;, score=0.880 total time=   6.8s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=80, min_samples_split=3, n_estimators=2000;, score=0.897 total time=   6.8s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=80, min_samples_split=3, n_estimators=2000;, score=0.694 total time=   6.6s
# [CV 1/3] END bootstrap=True, max_depth=9, max_features=auto, min_samples_leaf=80, min_samples_split=50, n_estimators=733;, score=0.886 total time=   2.0s
# [CV 2/3] END bootstrap=True, max_depth=9, max_features=auto, min_samples_leaf=80, min_samples_split=50, n_estimators=733;, score=0.902 total time=   1.9s
# [CV 3/3] END bootstrap=True, max_depth=9, max_features=auto, min_samples_leaf=80, min_samples_split=50, n_estimators=733;, score=0.698 total time=   1.9s
# {'n_estimators': 733,
#  'min_samples_split': 3,
#  'min_samples_leaf': 10,
#  'max_features': 'auto',
#  'max_depth': 13,
#  'bootstrap': False}

# %%
rdforest = RandomForestClassifier(rf_random.best_params_, random_state=42)
fit_result(model, X_train_final, y_train_final, X_test_final, y_test_final)
# Out:
# 對於主要目標 標籤為1的預測
# Precision：0.6623222748815166,             Recall：0.8830963665086888,
#         Accuracy：0.8205,        AUC：0.9084924379789463,        f1-score：0.7569397427217333
# [[1082  285]
#  [  74  559]]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.79      0.86      1367
#          1.0       0.66      0.88      0.76       633
#
#     accuracy                           0.82      2000
#    macro avg       0.80      0.84      0.81      2000
# weighted avg       0.85      0.82      0.83      2000
# The TP rate is: 0.79
# The TN rate is: 0.88
# The FN rate is: 0.21
# The FP rate is: 0.12

# %%
from sklearn.linear_model import LogisticRegression

model=LogisticRegression()
fit_result(model, X_train_final, y_train_final, X_test_final, y_test_final)
# Out:
# 對於主要目標 標籤為1的預測
# Precision：0.5809716599190283,             Recall：0.9067930489731437,
#         Accuracy：0.7635,        AUC：0.8947650035651923,        f1-score：0.7082048118445405
# [[953 414]
#  [ 59 574]]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.70      0.80      1367
#          1.0       0.58      0.91      0.71       633
#
#     accuracy                           0.76      2000
#    macro avg       0.76      0.80      0.75      2000
# weighted avg       0.83      0.76      0.77      2000
# The TP rate is:  0.7
# The TN rate is: 0.91
# The FN rate is:  0.3
# The FP rate is: 0.093

# %% [markdown]
# ## 主成分分析PCA+Ont hot encoding

# %%
np.shape(X_train)[1]
# Out:
# 17

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.decomposition import PCA
pca = PCA(n_components=np.shape(X_train)[1]).fit(X_train)

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlim(0, np.shape(X_train)[1], 1)
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0, 0.5, 'Cumulative explained variance')

# %%
#選擇15個主成份可解釋超過95% variance
pca = PCA(n_components=13)
pca.fit(X_train)
X_train_PCA = pca.transform(X_train)
X_test_PCA = pca.transform(X_test)

X_train_PCA = pd.DataFrame(
    X_train_PCA,
    columns=['PC-' + str(pc) for pc in list(range(1, X_train_PCA.shape[1] + 1))])
X_test_PCA = pd.DataFrame(
    X_test_PCA,
    columns=['PC-' + str(pc) for pc in list(range(1, X_test_PCA.shape[1] + 1))])

X_train_PCA
# Out:
#           PC-1      PC-2      PC-3      PC-4      PC-5      PC-6      PC-7  \
# 0     3.249135  0.512437 -0.062610  0.606130 -1.406651  0.383544 -1.282097
# 1    -2.112735  1.371206 -1.478277  1.896909 -0.667424  1.333876 -0.572693
# 2    -0.731102 -2.136630  0.649866  1.374999 -0.182298  0.300188  1.260665
# 3     1.338269 -1.357879 -0.512868  0.027902  0.405280 -0.959972 -0.909687
# 4    -1.089107 -1.036831  0.739639 -0.665895  1.554433  0.304167  1.018191
# ...        ...       ...       ...       ...       ...       ...       ...
# 7995  2.546955  0.810676  1.136546 -0.435091 -0.323672  0.327964  0.997017
# 7996 -1.748221 -1.475961  0.634814 -0.919636  1.368401  1.548070 -0.787721
# 7997  2.178444 -1.636938  0.042244 -0.044001 -1.257528 -0.125388 -0.860385
# 7998  3.499483 -1.020547  0.566468  0.868649 -0.414217  1.585571 -0.834647
# 7999 -2.080649  0.611470 -1.444207  0.882514  0.218992  2.036286  0.034995
#
#           PC-8      PC-9     PC-10     PC-11     PC-12     PC-13
# 0     0.614883 -0.423875  0.627842 -0.882531  1.522131  0.034475
# 1    -0.046839  0.321373  0.234777  0.007015 -1.248939  0.066703
# 2     0.040551  1.008894  1.026367 -0.953008  0.153016 -0.022834
# 3     0.468033  0.504472  0.890819 -1.699655  0.189894  0.902087
# 4     0.135048 -0.495802  0.033217 -0.143301 -0.235271 -0.163356
# ...        ...       ...       ...       ...       ...       ...
# 7995  0.133957  0.129558 -0.087596  0.217783 -1.452844 -0.179872
# 7996  0.405553  0.936630 -0.006009 -0.002196  1.006420  0.837342
# 7997  0.030465 -0.053687  0.342498 -0.171634  0.295186 -0.908987
# 7998 -0.108763 -0.345301  0.763078 -0.106310  0.417214  0.076970
# 7999 -0.880105  0.673153 -0.211490  0.080864 -0.226155 -0.428099
#
# [8000 rows x 13 columns]

# %%
model = DecisionTreeClassifier(splitter='random')
fit_result(model, X_train_PCA, y_train, X_test_PCA, y_test)
# Out:
# 對於主要目標 標籤為1的預測
# Precision：0.6126984126984127,             Recall：0.6097946287519748,
#         Accuracy：0.7545,        AUC：0.7156507891382404,        f1-score：0.611243072050673
# [[1123  244]
#  [ 247  386]]
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.82      0.82      1367
#          1.0       0.61      0.61      0.61       633
#
#     accuracy                           0.75      2000
#    macro avg       0.72      0.72      0.72      2000
# weighted avg       0.75      0.75      0.75      2000
# The TP rate is: 0.82
# The TN rate is: 0.61
# The FN rate is: 0.18
# The FP rate is: 0.39

# %% [markdown]
# #### 現在用數據增強過後的資料

# %%
pca_sm = PCA(n_components=np.shape(X_train_sm)[1]).fit(X_train_sm)

plt.plot(np.cumsum(pca_sm.explained_variance_ratio_))
plt.xlim(0, np.shape(X_train_sm)[1], 1)
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0, 0.5, 'Cumulative explained variance')

# %%
#選擇15個主成份可解釋超過95% variance
pca_sm = PCA(n_components=15)
pca.fit(X_train_sm)
X_train_PCA_sm = pca.transform(X_train_sm)
X_test_PCA_sm = pca.transform(X_test)

X_train_PCA_sm = pd.DataFrame(
    X_train_PCA_sm,
    columns=['PC-' + str(pc) for pc in list(range(1, X_train_PCA_sm.shape[1] + 1))])
X_test_PCA_sm = pd.DataFrame(
    X_test_PCA_sm,
    columns=['PC-' + str(pc) for pc in list(range(1, X_test_PCA_sm.shape[1] + 1))])

X_train_PCA_sm
# Out:
#           PC-1      PC-2      PC-3      PC-4      PC-5      PC-6      PC-7  \
# 0     3.172693 -0.276982  0.596298  0.110100 -1.505719  0.322826  1.327577
# 1    -0.884867  2.268681  0.012780  0.141104 -0.451041  0.365159 -1.209853
# 2     1.238236  0.984738 -1.003603  0.461826  0.316487 -0.710301  0.693601
# 3    -0.710302 -0.495000  0.403108 -0.284033 -0.758741 -0.255139 -0.905092
# 4    -1.006368 -0.263621  0.375015  1.227382 -0.562888 -1.357253 -0.077333
# ...        ...       ...       ...       ...       ...       ...       ...
# 7475 -1.022595  0.999407 -1.156090  0.010268  1.006810  1.572650  1.091823
# 7476  1.980758  1.595499 -0.437821  0.511675 -0.470031 -0.220161  0.966764
# 7477  1.880602 -0.047777 -0.241667  0.172584  0.729270  0.784409 -1.144458
# 7478 -0.769147 -0.274488  0.747661  0.124691 -0.571937  0.662198 -0.824091
# 7479 -0.459900 -0.073854  1.424807  0.314489  0.202741 -1.115270  2.623573
#
#           PC-8      PC-9     PC-10     PC-11     PC-12     PC-13
# 0    -1.021433  0.022228  1.136307  0.632191 -1.056067 -0.535781
# 1     0.246189  1.361849  1.210086  0.856966  0.296921  0.179421
# 2    -0.528083  1.235519  1.540081 -0.364176 -0.785216  0.915240
# 3    -0.784449  1.218735  1.376742  0.256070 -1.037299 -0.429944
# 4    -1.516516 -0.297622 -0.721738  0.298291 -0.074132  0.679858
# ...        ...       ...       ...       ...       ...       ...
# 7475  0.137221  0.319355 -1.323637  0.562266 -0.329975  0.019378
# 7476 -0.257454  0.180001  0.399376  0.384298 -0.040462 -0.465583
# 7477  0.078818 -0.362578 -0.166778 -0.170839  0.300973  0.371990
# 7478 -0.780364  1.093881  1.096543 -0.473085 -0.491482 -0.091265
# 7479 -0.477651 -0.869260  0.198000  0.012787  0.012162  0.618360
#
# [7480 rows x 13 columns]

# %%
X_test_PCA_sm #原本五萬多筆資料的1/5，沒有經過特徵增強，標sm只是在此方便辨識
# Out:
#           PC-1      PC-2      PC-3      PC-4      PC-5      PC-6      PC-7  \
# 0    -0.223695  0.141055  0.052914  1.724720 -0.398432 -0.736866 -0.046826
# 1     2.173337 -0.949389  0.403218 -0.353262 -1.140501 -0.584697 -1.192267
# 2    -4.494214  0.130111  2.025800  0.492886  0.219212 -1.020862  0.538162
# 3    -3.501152 -0.813689 -0.260751 -0.943934  0.198026  0.712874 -0.517796
# 4     2.192495  1.071936 -1.556953  0.442427 -0.857187 -0.177165  0.797338
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995 -1.912525  2.139207 -1.434506 -1.630007 -0.060575 -0.502081 -1.442687
# 1996 -0.001038 -0.137148  0.126548 -2.511155  0.232919 -0.632490 -1.204896
# 1997  0.287122 -1.118999  0.761676  0.120933 -1.012983  1.014910 -0.284940
# 1998 -2.049606 -1.010450  1.077248 -0.379548 -1.729421 -1.021999  0.184318
# 1999 -1.002513  1.124546 -1.235804  0.779871 -0.472979  0.325275  1.411389
#
#           PC-8      PC-9     PC-10     PC-11     PC-12     PC-13
# 0     0.955632 -0.724112  0.829386 -0.251387  0.347107 -0.184333
# 1     0.152743  1.491737  1.258075 -0.137720 -0.747670  0.082652
# 2    -0.322416  0.723765  1.297101  1.413764  0.524100  0.361817
# 3    -1.135790  0.770662 -0.403607 -0.539300  0.172157  1.253759
# 4     0.153537  0.168592  0.185501  0.197415 -0.266842  0.253582
# ...        ...       ...       ...       ...       ...       ...
# 1995  0.680300  0.145351 -0.145707  0.085853 -0.625336  0.598704
# 1996  0.030340  0.421545 -0.411435 -0.592948  0.966765  0.333243
# 1997 -1.558483 -0.243545  0.129088 -0.809894  1.195614  0.001511
# 1998 -2.103520 -0.327860 -0.605133  0.455161  0.672136 -0.574572
# 1999 -0.061664  0.580107 -1.343565  0.798644 -1.090538  0.744282
#
# [2000 rows x 13 columns]

# %%
model = DecisionTreeClassifier(splitter='random')
fit_result(model, X_train_PCA_sm, y_train_sm, X_test_PCA_sm, y_test)
# Out:
# 對於主要目標 標籤為1的預測
# Precision：0.5679824561403509,             Recall：0.8183254344391785,
#         Accuracy：0.7455,        AUC：0.7650515248274898,        f1-score：0.6705501618122978
# [[973 394]
#  [115 518]]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.71      0.79      1367
#          1.0       0.57      0.82      0.67       633
#
#     accuracy                           0.75      2000
#    macro avg       0.73      0.77      0.73      2000
# weighted avg       0.79      0.75      0.75      2000
# The TP rate is: 0.71
# The TN rate is: 0.82
# The FN rate is: 0.29
# The FP rate is: 0.18

# %%
X_train
# Out:
#            AGE    GENDER      RACE  DRIVING_EXPERIENCE  EDUCATION    INCOME  \
# 0    -0.924044 -1.066367 -0.233246           -1.138878   0.087149 -0.900274
# 1     0.069008  0.704061 -0.669936            1.285899   1.793799  1.767215
# 2     0.070896 -0.977978 -1.880052            1.255789  -0.897356 -0.221616
# 3    -0.691115 -1.008799 -0.041609           -0.283032   0.062556 -0.867563
# 4    -0.691580  1.035805 -0.083561            1.268646  -0.903305 -0.171144
# ...        ...       ...       ...                 ...        ...       ...
# 7995 -0.924882  1.097259 -0.129993           -1.148506   0.097496 -0.874525
# 7996  1.780714  1.128556 -0.172320            1.290412  -0.945007  0.665540
# 7997 -0.924288 -1.067538 -0.179116           -1.144416  -0.950017 -0.882410
# 7998 -0.848624  0.545443 -1.340030           -1.083527  -1.126567 -1.039065
# 7999  1.788438  1.088066 -0.104860            1.266778   0.087498  0.646325
#
#       CREDIT_SCORE  VEHICLE_OWNERSHIP  VEHICLE_YEAR   MARRIED  CHILDREN  \
# 0         0.231601           0.661480     -1.526241  0.997004  0.677143
# 1        -1.177864          -1.511761      0.564189  0.997004  0.677143
# 2         0.158058           0.661480      0.549875  0.997004 -1.476792
# 3         0.747094           0.661480     -1.507686  0.997004 -1.476792
# 4        -0.314774           0.661480      0.644004 -1.003005 -1.476792
# ...            ...                ...           ...       ...       ...
# 7995      1.367429           0.661480      0.662910  0.997004  0.677143
# 7996      0.051440           0.661480     -1.541378 -1.003005 -1.476792
# 7997      0.850495           0.661480     -1.543458  0.997004  0.677143
# 7998      1.732647           0.661480     -1.632595  0.997004  0.677143
# 7999     -1.322063          -1.511761      0.647126  0.997004  0.677143
#
#       POSTAL_CODE  ANNUAL_MILEAGE  VEHICLE_TYPE  SPEEDING_VIOLATIONS  \
# 0       -0.511636       -1.380447     -0.130468             1.111686
# 1       -0.511636       -1.006844     -0.517924            -0.661338
# 2       -0.511636        0.113963     -0.697216            -0.661338
# 3        0.685773       -1.006844      0.025767             0.668430
# 4        0.685773        0.487566     -0.039890            -0.661338
# ...           ...             ...           ...                  ...
# 7995    -0.511636        0.861168      0.023362             0.668430
# 7996    -0.511636       -0.259639      0.143387            -0.661338
# 7997    -0.511636        0.000763     -0.001979            -0.661338
# 7998    -0.511636       -1.380447     -0.436923            -0.218082
# 7999    -0.511636       -0.633242     -0.053891            -0.661338
#
#           DUIS  PAST_ACCIDENTS
# 0    -0.433018        2.940435
# 1    -0.433018       -0.642457
# 2    -0.433018       -0.642457
# 3    -0.433018       -0.642457
# 4    -0.433018       -0.642457
# ...        ...             ...
# 7995  1.346202        1.148989
# 7996 -0.433018       -0.642457
# 7997 -0.433018        0.551840
# 7998 -0.433018        2.343286
# 7999 -0.433018       -0.642457
#
# [8000 rows x 17 columns]
