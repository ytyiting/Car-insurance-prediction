# %% [markdown]
# # MDS Final Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
import category_encoders as ce  # Leave-one-out, CatBoost, Heimert coding
from sklearn.preprocessing import StandardScaler  # label encoder, 標準化
from sklearn.cluster import DBSCAN  # outlier detection
from sklearn.model_selection import train_test_split, GridSearchCV  # split data into train data & test data

import warnings
warnings.filterwarnings('ignore')
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['figure.titlesize'] = 16
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['legend.fontsize'] = 10

# %% [markdown]
# <div></div>

# %% [markdown]
# <div></div>

# %% [markdown]
# <div style="background-color:#D9D9D9;"><font size="20"><b>Data Reading and Analysis</b></font></div>

# %%
#基本不更動raw_data, 之後都用df操作

# %%
raw_data = pd.read_csv('Car_Insurance_Claim.csv').drop(['ID'], axis=1)
display(raw_data.head())
display(raw_data.tail())
# Out:
#      AGE  GENDER      RACE DRIVING_EXPERIENCE    EDUCATION         INCOME  \
# 0    65+  female  majority               0-9y  high school    upper class
# 1  16-25    male  majority               0-9y         none        poverty
# 2  16-25  female  majority               0-9y  high school  working class
# 3  16-25    male  majority               0-9y   university  working class
# 4  26-39    male  majority             10-19y         none  working class
#
#    CREDIT_SCORE  VEHICLE_OWNERSHIP VEHICLE_YEAR  MARRIED  CHILDREN  \
# 0      0.629027                1.0   after 2015      0.0       1.0
# 1      0.357757                0.0  before 2015      0.0       0.0
# 2      0.493146                1.0  before 2015      0.0       0.0
# 3      0.206013                1.0  before 2015      0.0       1.0
# 4      0.388366                1.0  before 2015      0.0       0.0
#
#    POSTAL_CODE  ANNUAL_MILEAGE VEHICLE_TYPE  SPEEDING_VIOLATIONS  DUIS  \
# 0        10238         12000.0        sedan                    0     0
# 1        10238         16000.0        sedan                    0     0
# 2        10238         11000.0        sedan                    0     0
# 3        32765         11000.0        sedan                    0     0
# 4        32765         12000.0        sedan                    2     0
#
#    PAST_ACCIDENTS  OUTCOME
# 0               0      0.0
# 1               0      1.0
# 2               0      0.0
# 3               0      0.0
# 4               1      1.0
#         AGE  GENDER      RACE DRIVING_EXPERIENCE    EDUCATION         INCOME  \
# 9995  26-39  female  majority             10-19y   university    upper class
# 9996  26-39  female  majority             10-19y         none   middle class
# 9997  26-39    male  majority               0-9y  high school   middle class
# 9998  26-39  female  majority             10-19y  high school        poverty
# 9999  26-39  female  majority               0-9y         none  working class
#
#       CREDIT_SCORE  VEHICLE_OWNERSHIP VEHICLE_YEAR  MARRIED  CHILDREN  \
# 9995      0.582787                1.0  before 2015      0.0       0.0
# 9996      0.522231                1.0   after 2015      0.0       1.0
# 9997      0.470940                1.0  before 2015      0.0       1.0
# 9998      0.364185                0.0  before 2015      0.0       1.0
# 9999      0.435225                1.0  before 2015      1.0       1.0
#
#       POSTAL_CODE  ANNUAL_MILEAGE VEHICLE_TYPE  SPEEDING_VIOLATIONS  DUIS  \
# 9995        10238         16000.0        sedan                    0     0
# 9996        32765             NaN        sedan                    1     0
# 9997        10238         14000.0        sedan                    0     0
# 9998        10238         13000.0        sedan                    2     0
# 9999        10238         13000.0        sedan                    0     0
#
#       PAST_ACCIDENTS  OUTCOME
# 9995               1      0.0
# 9996               0      0.0
# 9997               0      0.0
# 9998               1      1.0
# 9999               0      0.0

# %%
print('The dimension of train dataset: ', raw_data.shape)
raw_data['OUTCOME'].value_counts()
# Out:
# The dimension of train dataset:  (10000, 18)
# 0.0    6867
# 1.0    3133
# Name: OUTCOME, dtype: int64

# %% [markdown]
# <font size="5" >🔼 Severe data imbalance!</font>

# %% [markdown]
# <div></div>

# %%
raw_data.describe()
# Out:
#        CREDIT_SCORE  VEHICLE_OWNERSHIP       MARRIED      CHILDREN  \
# count   9018.000000       10000.000000  10000.000000  10000.000000
# mean       0.515813           0.697000      0.498200      0.688800
# std        0.137688           0.459578      0.500022      0.463008
# min        0.053358           0.000000      0.000000      0.000000
# 25%        0.417191           0.000000      0.000000      0.000000
# 50%        0.525033           1.000000      0.000000      1.000000
# 75%        0.618312           1.000000      1.000000      1.000000
# max        0.960819           1.000000      1.000000      1.000000
#
#         POSTAL_CODE  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS         DUIS  \
# count  10000.000000     9043.000000         10000.000000  10000.00000
# mean   19864.548400    11697.003207             1.482900      0.23920
# std    18915.613855     2818.434528             2.241966      0.55499
# min    10238.000000     2000.000000             0.000000      0.00000
# 25%    10238.000000    10000.000000             0.000000      0.00000
# 50%    10238.000000    12000.000000             0.000000      0.00000
# 75%    32765.000000    14000.000000             2.000000      0.00000
# max    92101.000000    22000.000000            22.000000      6.00000
#
#        PAST_ACCIDENTS       OUTCOME
# count    10000.000000  10000.000000
# mean         1.056300      0.313300
# std          1.652454      0.463858
# min          0.000000      0.000000
# 25%          0.000000      0.000000
# 50%          0.000000      0.000000
# 75%          2.000000      1.000000
# max         15.000000      1.000000

# %%
percentage_result = raw_data.isnull().sum()/raw_data.shape[0]
percentage_result = pd.DataFrame({"missing": percentage_result}) #"columns": percentage_result.keys(), 
percentage_result.sort_values(by='missing', ascending=False).head()
# Out:
#                 missing
# CREDIT_SCORE     0.0982
# ANNUAL_MILEAGE   0.0957
# AGE              0.0000
# CHILDREN         0.0000
# PAST_ACCIDENTS   0.0000

# %% [markdown]
# <font size="3" >🔼<br>
# 由上可以知道<b>沒有資料缺失</b>，接著處理類別變數<br>
# 發現眾多欄位包含'Yes'/'No', 將其與其他類別變數分開處理<br></font>

# %%
raw_data.fillna(raw_data.mean(),inplace=True)
percentage_result = raw_data.isnull().sum()/raw_data.shape[0]
percentage_result = pd.DataFrame({"missing": percentage_result}) #"columns": percentage_result.keys(), 
percentage_result.sort_values(by='missing', ascending=False).head()
# Out:
#                      missing
# AGE                      0.0
# GENDER                   0.0
# PAST_ACCIDENTS           0.0
# DUIS                     0.0
# SPEEDING_VIOLATIONS      0.0

# %% [markdown]
# <div></div>

# %% [markdown]
# <div></div>

# %% [markdown]
# <div style="background-color:#D9D9D9;"><font size="20"><b>Preprocessing</b></font></div>

# %% [markdown]
# ### 處理順序：
# 先編碼(encode)，再分割訓練測試集(split)，再對「訓練集」標準化(standardize)<br>
# [編碼、標準化、分割順序要怎麼選](https://jamesmccaffrey-wordpress-com.translate.goog/2020/05/27/should-you-normalize-and-encode-data-before-train-test-splitting-or-after-splitting/?_x_tr_sl=auto&_x_tr_tl=zh-CN&_x_tr_hl=zh-CN)

# %% [markdown]
# - 類別變數：
#     - 其中make為隱藏的車子製造商1~5, model為車子名稱(兩萬多種),
#     - 'area_cluster', 'make', 'segment', 'model', 'fuel_type', 'max_torque', 'max_power', 'engine_type', 'rear_brakes_type', 'transmission_type', 'steering_type'
# - Y/N變數：
#     - 'is_esc', 'is_adjustable_steering', 'is_tpms', 'is_parking_sensors', 'is_parking_camera', 'is_front_fog_lights', 'is_rear_window_wiper', 'is_rear_window_washer', 'is_rear_window_defogger', 'is_brake_assist', 'is_power_door_locks', 'is_central_locking', 'is_power_steering', 'is_driver_seat_height_adjustable', 'is_day_night_rear_view_mirror', 'is_ecw', 'is_speed_alert'

# %%
df = raw_data
# df.replace(['Yes', 'No'], [1,0], inplace=True)
# df['make'].replace([1,2,3,4,5], ['C1','C2','C3','C4','C5'], inplace=True)
display(df)
# Out:
#         AGE  GENDER      RACE DRIVING_EXPERIENCE    EDUCATION         INCOME  \
# 0       65+  female  majority               0-9y  high school    upper class
# 1     16-25    male  majority               0-9y         none        poverty
# 2     16-25  female  majority               0-9y  high school  working class
# 3     16-25    male  majority               0-9y   university  working class
# 4     26-39    male  majority             10-19y         none  working class
# ...     ...     ...       ...                ...          ...            ...
# 9995  26-39  female  majority             10-19y   university    upper class
# 9996  26-39  female  majority             10-19y         none   middle class
# 9997  26-39    male  majority               0-9y  high school   middle class
# 9998  26-39  female  majority             10-19y  high school        poverty
# 9999  26-39  female  majority               0-9y         none  working class
#
#       CREDIT_SCORE  VEHICLE_OWNERSHIP VEHICLE_YEAR  MARRIED  CHILDREN  \
# 0         0.629027                1.0   after 2015      0.0       1.0
# 1         0.357757                0.0  before 2015      0.0       0.0
# 2         0.493146                1.0  before 2015      0.0       0.0
# 3         0.206013                1.0  before 2015      0.0       1.0
# 4         0.388366                1.0  before 2015      0.0       0.0
# ...            ...                ...          ...      ...       ...
# 9995      0.582787                1.0  before 2015      0.0       0.0
# 9996      0.522231                1.0   after 2015      0.0       1.0
# 9997      0.470940                1.0  before 2015      0.0       1.0
# 9998      0.364185                0.0  before 2015      0.0       1.0
# 9999      0.435225                1.0  before 2015      1.0       1.0
#
#       POSTAL_CODE  ANNUAL_MILEAGE VEHICLE_TYPE  SPEEDING_VIOLATIONS  DUIS  \
# 0           10238    12000.000000        sedan                    0     0
# 1           10238    16000.000000        sedan                    0     0
# 2           10238    11000.000000        sedan                    0     0
# 3           32765    11000.000000        sedan                    0     0
# 4           32765    12000.000000        sedan                    2     0
# ...           ...             ...          ...                  ...   ...
# 9995        10238    16000.000000        sedan                    0     0
# 9996        32765    11697.003207        sedan                    1     0
# 9997        10238    14000.000000        sedan                    0     0
# 9998        10238    13000.000000        sedan                    2     0
# 9999        10238    13000.000000        sedan                    0     0
#
#       PAST_ACCIDENTS  OUTCOME
# 0                  0      0.0
# 1                  0      1.0
# 2                  0      0.0
# 3                  0      0.0
# 4                  1      1.0
# ...              ...      ...
# 9995               1      0.0
# 9996               0      0.0
# 9997               0      0.0
# 9998               1      1.0
# 9999               0      0.0
#
# [10000 rows x 18 columns]

# %% [markdown]
# ## 首先把Yes轉為1, No轉為0

# %% [markdown]
# ## 主成分分析PCA+One hot encoding

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.decomposition import PCA

# %% [markdown]
# ### One hot encoding

# %%
df = pd.get_dummies(df)
df
# Out:
#       CREDIT_SCORE  VEHICLE_OWNERSHIP  MARRIED  CHILDREN  POSTAL_CODE  \
# 0         0.629027                1.0      0.0       1.0        10238
# 1         0.357757                0.0      0.0       0.0        10238
# 2         0.493146                1.0      0.0       0.0        10238
# 3         0.206013                1.0      0.0       1.0        32765
# 4         0.388366                1.0      0.0       0.0        32765
# ...            ...                ...      ...       ...          ...
# 9995      0.582787                1.0      0.0       0.0        10238
# 9996      0.522231                1.0      0.0       1.0        32765
# 9997      0.470940                1.0      0.0       1.0        10238
# 9998      0.364185                0.0      0.0       1.0        10238
# 9999      0.435225                1.0      1.0       1.0        10238
#
#       ANNUAL_MILEAGE  SPEEDING_VIOLATIONS  DUIS  PAST_ACCIDENTS  OUTCOME  ...  \
# 0       12000.000000                    0     0               0      0.0  ...
# 1       16000.000000                    0     0               0      1.0  ...
# 2       11000.000000                    0     0               0      0.0  ...
# 3       11000.000000                    0     0               0      0.0  ...
# 4       12000.000000                    2     0               1      1.0  ...
# ...              ...                  ...   ...             ...      ...  ...
# 9995    16000.000000                    0     0               1      0.0  ...
# 9996    11697.003207                    1     0               0      0.0  ...
# 9997    14000.000000                    0     0               0      0.0  ...
# 9998    13000.000000                    2     0               1      1.0  ...
# 9999    13000.000000                    0     0               0      0.0  ...
#
#       EDUCATION_none  EDUCATION_university  INCOME_middle class  \
# 0                  0                     0                    0
# 1                  1                     0                    0
# 2                  0                     0                    0
# 3                  0                     1                    0
# 4                  1                     0                    0
# ...              ...                   ...                  ...
# 9995               0                     1                    0
# 9996               1                     0                    1
# 9997               0                     0                    1
# 9998               0                     0                    0
# 9999               1                     0                    0
#
#       INCOME_poverty  INCOME_upper class  INCOME_working class  \
# 0                  0                   1                     0
# 1                  1                   0                     0
# 2                  0                   0                     1
# 3                  0                   0                     1
# 4                  0                   0                     1
# ...              ...                 ...                   ...
# 9995               0                   1                     0
# 9996               0                   0                     0
# 9997               0                   0                     0
# 9998               1                   0                     0
# 9999               0                   0                     1
#
#       VEHICLE_YEAR_after 2015  VEHICLE_YEAR_before 2015  VEHICLE_TYPE_sedan  \
# 0                           1                         0                   1
# 1                           0                         1                   1
# 2                           0                         1                   1
# 3                           0                         1                   1
# 4                           0                         1                   1
# ...                       ...                       ...                 ...
# 9995                        0                         1                   1
# 9996                        1                         0                   1
# 9997                        0                         1                   1
# 9998                        0                         1                   1
# 9999                        0                         1                   1
#
#       VEHICLE_TYPE_sports car
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           0
# ...                       ...
# 9995                        0
# 9996                        0
# 9997                        0
# 9998                        0
# 9999                        0
#
# [10000 rows x 33 columns]

# %%
target = [i for i in df.columns]
plt.figure(figsize=(10,100))

for n,column in enumerate(target):
    plot=plt.subplot(int((len(target)+1) / 2),2,n+1)
    sns.distplot(df[column],color='green')
    plt.title(f'{column.title()}',weight='bold')
    plt.tight_layout()

# %% [markdown]
# <div></div>

# %% [markdown]
# ### RadViz
#
# 是一種多元數據可視化算法，它將每個特徵維度均勻地繪制在圓周上，然後在圓的內部繪制點，使點在從中心到每個弧的軸上的值歸一化。這種機制允許有多少維度就有多少維度，可以很容易地適應一個圓，大大擴展了可視化的維度。
# 可以使用這種方法來檢測類之間的可分離性。如
# - 是否有機會從特徵集中學習
# - 檢查是否有太多的噪音

# %%
from yellowbrick.features import RadViz


visualizer = RadViz(classes=df['OUTCOME'].unique(),
                    features=list(df.columns[:-1]), size=(720, 720))
visualizer.fit(df.iloc[:,:-1].values, df['OUTCOME'].values)
visualizer.transform(df[:-1].values)
visualizer.poof()
# Out:
# <AxesSubplot: title={'center': 'RadViz for 32 Features'}>

# %% [markdown]
# <font size="3" >🔼上圖看起來標籤的分類沒有很明確，故不期待結果準確區分is_claim，本身是具有偏大難度</font>

# %% [markdown]
# <div></div>

# %% [markdown]
# ## 處理資料不平衡

# %% [markdown]
# 為了避免受到噪音干擾，同時採用`ENN`(Edited Nearest Neighbor)和`Borderline Smote`進行採樣<br>
# - ENN可以改為Tomek Link Removal，Borderline Smote可以改為單純Smote<br>
# - 也可以試著採用集成方法Ensemble(BalanceCascade)
# - http://www.17bigdata.com/聊聊样本采样技术/ <br><br>
# NOTE: 採樣前得先對數據標準化，標準化之前先分好訓練集&測試集

# %%
X = df.drop('OUTCOME',axis=1)
y = df['OUTCOME']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# <div></div>

# %% [markdown]
# ### Scaler

# %%
from sklearn.preprocessing import StandardScaler
standard_scaler = StandardScaler()
X_train = pd.DataFrame(standard_scaler.fit_transform(X_train), columns=X_train.columns) #先fit
X_test = pd.DataFrame(standard_scaler.transform(X_test), columns=X_test.columns) #再transform
X_train
# Out:
#       CREDIT_SCORE  VEHICLE_OWNERSHIP   MARRIED  CHILDREN  POSTAL_CODE  \
# 0         0.231601           0.661480  0.997004  0.677143    -0.511636
# 1        -1.177864          -1.511761  0.997004  0.677143    -0.511636
# 2         0.158058           0.661480  0.997004 -1.476792    -0.511636
# 3         0.747094           0.661480  0.997004 -1.476792     0.685773
# 4        -0.314774           0.661480 -1.003005 -1.476792     0.685773
# ...            ...                ...       ...       ...          ...
# 7995      1.367429           0.661480  0.997004  0.677143    -0.511636
# 7996      0.051440           0.661480 -1.003005 -1.476792    -0.511636
# 7997      0.850495           0.661480  0.997004  0.677143    -0.511636
# 7998      1.732647           0.661480  0.997004  0.677143    -0.511636
# 7999     -1.322063          -1.511761  0.997004  0.677143    -0.511636
#
#       ANNUAL_MILEAGE  SPEEDING_VIOLATIONS      DUIS  PAST_ACCIDENTS  \
# 0          -1.380447             1.111686 -0.433018        2.940435
# 1          -1.006844            -0.661338 -0.433018       -0.642457
# 2           0.113963            -0.661338 -0.433018       -0.642457
# 3          -1.006844             0.668430 -0.433018       -0.642457
# 4           0.487566            -0.661338 -0.433018       -0.642457
# ...              ...                  ...       ...             ...
# 7995        0.861168             0.668430  1.346202        1.148989
# 7996       -0.259639            -0.661338 -0.433018       -0.642457
# 7997        0.000763            -0.661338 -0.433018        0.551840
# 7998       -1.380447            -0.218082 -0.433018        2.343286
# 7999       -0.633242            -0.661338 -0.433018       -0.642457
#
#       AGE_16-25  ...  EDUCATION_none  EDUCATION_university  \
# 0     -0.503318  ...       -0.485502             -0.811403
# 1     -0.503318  ...        2.059724             -0.811403
# 2     -0.503318  ...       -0.485502              1.232433
# 3     -0.503318  ...       -0.485502             -0.811403
# 4     -0.503318  ...       -0.485502              1.232433
# ...         ...  ...             ...                   ...
# 7995  -0.503318  ...       -0.485502             -0.811403
# 7996   1.986815  ...       -0.485502              1.232433
# 7997  -0.503318  ...       -0.485502              1.232433
# 7998  -0.503318  ...       -0.485502              1.232433
# 7999   1.986815  ...       -0.485502             -0.811403
#
#       INCOME_middle class  INCOME_poverty  INCOME_upper class  \
# 0               -0.523728       -0.469513            1.145486
# 1               -0.523728        2.129867           -0.872992
# 2                1.909388       -0.469513           -0.872992
# 3               -0.523728       -0.469513            1.145486
# 4                1.909388       -0.469513           -0.872992
# ...                   ...             ...                 ...
# 7995            -0.523728       -0.469513            1.145486
# 7996            -0.523728       -0.469513           -0.872992
# 7997            -0.523728       -0.469513            1.145486
# 7998            -0.523728       -0.469513            1.145486
# 7999            -0.523728       -0.469513           -0.872992
#
#       INCOME_working class  VEHICLE_YEAR_after 2015  VEHICLE_YEAR_before 2015  \
# 0                -0.455173                 1.533914                 -1.533914
# 1                -0.455173                -0.651927                  0.651927
# 2                -0.455173                -0.651927                  0.651927
# 3                -0.455173                 1.533914                 -1.533914
# 4                -0.455173                -0.651927                  0.651927
# ...                    ...                      ...                       ...
# 7995             -0.455173                -0.651927                  0.651927
# 7996              2.196965                 1.533914                 -1.533914
# 7997             -0.455173                 1.533914                 -1.533914
# 7998             -0.455173                 1.533914                 -1.533914
# 7999              2.196965                -0.651927                  0.651927
#
#       VEHICLE_TYPE_sedan  VEHICLE_TYPE_sports car
# 0               0.221456                -0.221456
# 1               0.221456                -0.221456
# 2               0.221456                -0.221456
# 3               0.221456                -0.221456
# 4               0.221456                -0.221456
# ...                  ...                      ...
# 7995            0.221456                -0.221456
# 7996            0.221456                -0.221456
# 7997            0.221456                -0.221456
# 7998            0.221456                -0.221456
# 7999            0.221456                -0.221456
#
# [8000 rows x 32 columns]

# %%
from collections import Counter
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# %%
from sklearn import metrics
def fit_result(model, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)
    predicted_y = model.predict(X_test)
    true_y = y_test
    
    print("對於主要目標 標籤為1的預測")
    print(f"Precision：{metrics.precision_score(true_y, predicted_y)}, \
            Recall：{metrics.recall_score(true_y, predicted_y)},\n \
       Accuracy：{metrics.accuracy_score(true_y, predicted_y)}, \
       AUC：{metrics.roc_auc_score(true_y, model.predict_proba(X_test)[:,1])}, \
       f1-score：{metrics.f1_score(true_y, predicted_y)}")
    cm = confusion_matrix(true_y, predicted_y)
    print(cm) 
    print(metrics.classification_report(true_y, predicted_y))
    
    #此處-1是先的label容易搞混，但我們就照平常的方法來不管此例是-1還是1
    fig, ax = plt.subplots(figsize=(5, 5))
    plot_confusion_matrix(model, X_test, y_test,  cmap=plt.cm.Blues, colorbar=False, ax=ax)
    plt.show()
    
    #已驗算過
    print('The TP rate is: {0:4.2}'.format(float(cm[0][0])/np.sum(cm[0])))
    print('The TN rate is: {0:4.2}'.format(float(cm[1][1])/np.sum(cm[1])))
    print('The FN rate is: {0:4.2}'.format(1- float(cm[0][0])/np.sum(cm[0]))) #FN = 1-TP
    print('The FP rate is: {0:4.2}'.format(1- float(cm[1][1])/np.sum(cm[1]))) #FP = 1-TN

# %% [markdown]
# ### Baseline performance

# %%
pca = PCA(n_components=np.shape(X_train)[1]).fit(X_train)

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlim(0, np.shape(X_train)[1], 1)
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0, 0.5, 'Cumulative explained variance')

# %%
#選擇15個主成份可解釋超過95% variance
pca = PCA(n_components=15)
pca.fit(X_train)
X_train_PCA = pca.transform(X_train)
X_test_PCA = pca.transform(X_test)

X_train_PCA = pd.DataFrame(
    X_train_PCA,
    columns=['PC-' + str(pc) for pc in list(range(1, X_train_PCA.shape[1] + 1))])
X_test_PCA = pd.DataFrame(
    X_test_PCA,
    columns=['PC-' + str(pc) for pc in list(range(1, X_test_PCA.shape[1] + 1))])

X_train_PCA
# Out:
#           PC-1      PC-2      PC-3      PC-4      PC-5      PC-6      PC-7  \
# 0     3.891924 -1.458997  0.183371 -1.830365  1.826209  0.155917 -1.950263
# 1    -2.537573 -0.128717  1.803833 -0.503906 -0.553133 -0.171733  0.002470
# 2    -1.299925  0.937637 -0.507651  0.475210  3.179029 -1.185541  2.050494
# 3     1.611718  0.525186 -2.552384  0.244157  0.337218 -0.521521 -0.020865
# 4    -1.028251 -0.333969 -0.213120  0.747275 -2.238713 -0.217527  1.068482
# ...        ...       ...       ...       ...       ...       ...       ...
# 7995  2.938321 -1.065891  2.350782 -1.492781  0.292749  0.442737 -1.921419
# 7996 -1.276505 -1.628133 -0.633382 -1.446339 -1.877140 -0.446749  2.444373
# 7997  3.309994 -1.674943 -1.345473 -2.616758  1.395616 -0.078754 -0.231489
# 7998  3.965895 -0.677755 -0.501744  1.421303 -1.823225 -0.586439  1.660357
# 7999 -2.445991 -1.252226  1.203457 -0.006998 -1.062854  0.149722 -0.593585
#
#           PC-8      PC-9     PC-10     PC-11     PC-12     PC-13     PC-14  \
# 0     2.067046  1.198616 -0.456418 -0.177300 -0.394628 -1.226292  0.031140
# 1    -1.477455  1.095731 -2.566605 -0.787070 -1.208257 -0.837958  0.026954
# 2    -0.760683 -2.822245  0.892377 -1.740231  1.002194 -0.611716 -0.457505
# 3     1.336116  0.836029 -0.905752  0.580538 -0.732515  1.337720  0.610896
# 4    -0.569745 -1.810779  1.016656 -1.396284  1.486567  0.347036  0.442012
# ...        ...       ...       ...       ...       ...       ...       ...
# 7995  1.213313 -0.871473  1.270251  0.159886 -0.956977 -0.047187  0.913180
# 7996  0.781332 -0.257044  0.264830  1.628299  1.783519 -1.209500 -0.233053
# 7997 -0.163789  0.602080  0.525410 -0.244828  0.143937 -1.166501 -0.035220
# 7998 -0.239652  0.557249 -0.620702  0.080739 -0.896086 -1.126763 -0.283894
# 7999  1.163827 -1.418283 -1.927286  1.905313  0.196741 -1.485139 -1.186064
#
#          PC-15
# 0    -0.563768
# 1     0.000200
# 2     1.015117
# 3     0.318280
# 4    -0.367796
# ...        ...
# 7995 -0.052240
# 7996  0.866011
# 7997 -0.584511
# 7998 -0.337332
# 7999  0.299654
#
# [8000 rows x 15 columns]

# %%
model = DecisionTreeClassifier(splitter='random')
fit_result(model, X_train_PCA, y_train, X_test_PCA, y_test)
# Out:
# 對於主要目標 標籤為1的預測
# Precision：0.614516129032258,             Recall：0.6018957345971564,
#         Accuracy：0.7545,        AUC：0.714043852441492,        f1-score：0.6081404628890662
# [[1128  239]
#  [ 252  381]]
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.83      0.82      1367
#          1.0       0.61      0.60      0.61       633
#
#     accuracy                           0.75      2000
#    macro avg       0.72      0.71      0.71      2000
# weighted avg       0.75      0.75      0.75      2000
# The TP rate is: 0.83
# The TN rate is:  0.6
# The FN rate is: 0.17
# The FP rate is:  0.4

# %% [markdown]
# <div></div>

# %% [markdown]
# ### CrossCV測試樣本比例
#
# #### *****之後記得把kind_sel的模式改看看，也可以試試一般的ENN*****
# https://blog.csdn.net/mathlxj/article/details/89645321
# (mode只刪了626筆，另一個能刪除一萬多)

# %%
from imblearn.under_sampling import RepeatedEditedNearestNeighbours
from imblearn.under_sampling import EditedNearestNeighbours
from imblearn.over_sampling import BorderlineSMOTE
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline


model = DecisionTreeClassifier(splitter='random')
# print("before data balancing：",Counter(y_train))
# print()

# for i in np.linspace(0.2, 1, 9):
#     for j in range(3, 9, 2):   
#         renn = RepeatedEditedNearestNeighbours()#kind_sel='mode'
#         BDsmote = BorderlineSMOTE(m_neighbors=j, sampling_strategy=i)
#         steps = [('under(renn)', renn), ('over(BDsmote)', BDsmote)]
#         pipeline = Pipeline(steps=steps)
#         X_cv, y_cv = pipeline.fit_resample(X_train, y_train)

#         #重複兩次 5-fold來評分
#         cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=2, random_state=42)
#         scores = cross_val_score(model, X_cv, y_cv, scoring='f1_macro', cv=cv) #n_jobs為一次運行多少processor
#         print(f'ratio={i}, m={j}, Mean f1_macro: %.3f' % np.mean(scores))
#     print("after data balancing:",Counter(y_cv))
#     print()
#     #print("after data balancing:",Counter(y_cv))

# %% [markdown]
# <font size="3" >
#     🔼<br>
#     發現在樣本數為1:1，BorderlineSMOTE m=3的情況下會得到較好的f1_macro值<br>
#     <b>注意:</b> 此結果是基於兩 label 的資料分布有改變後的結果，才會有此好的結果在f1_macro
# </font>

# %% [markdown]
# <div></div>

# %% [markdown]
# ### 正式將訓練資料重新取樣 -> `X_train_PCA_sm`,` y_train_sm`, `X_test_PCA_sm`, `y_test`

# %%
renn = EditedNearestNeighbours()#kind_sel='mode'
BDsmote = BorderlineSMOTE(m_neighbors=3, sampling_strategy=1.0)
steps = [('under(renn)', renn), ('over(BDsmote)', BDsmote)]
pipeline = Pipeline(steps=steps)
X_train_sm, y_train_sm = pipeline.fit_resample(X_train, y_train)

model = DecisionTreeClassifier(splitter='random')
fit_result(model, X_train_sm, y_train_sm, X_test, y_test)
# Out:
# 對於主要目標 標籤為1的預測
# Precision：0.6020524515393386,             Recall：0.8341232227488151,
#         Accuracy：0.773,        AUC：0.7894098191286139,        f1-score：0.6993377483443708
# [[1018  349]
#  [ 105  528]]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.74      0.82      1367
#          1.0       0.60      0.83      0.70       633
#
#     accuracy                           0.77      2000
#    macro avg       0.75      0.79      0.76      2000
# weighted avg       0.81      0.77      0.78      2000
# The TP rate is: 0.74
# The TN rate is: 0.83
# The FN rate is: 0.26
# The FP rate is: 0.17

# %%
pca_sm = PCA(n_components=np.shape(X_train_sm)[1]).fit(X_train_sm)

plt.plot(np.cumsum(pca_sm.explained_variance_ratio_))
plt.xlim(0, np.shape(X_train_sm)[1], 1)
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0, 0.5, 'Cumulative explained variance')

# %%
#選擇15個主成份可解釋超過95% variance
pca_sm = PCA(n_components=15)
pca.fit(X_train_sm)
X_train_PCA_sm = pca.transform(X_train_sm)
X_test_PCA_sm = pca.transform(X_test)

X_train_PCA_sm = pd.DataFrame(
    X_train_PCA_sm,
    columns=['PC-' + str(pc) for pc in list(range(1, X_train_PCA_sm.shape[1] + 1))])
X_test_PCA_sm = pd.DataFrame(
    X_test_PCA_sm,
    columns=['PC-' + str(pc) for pc in list(range(1, X_test_PCA_sm.shape[1] + 1))])

X_train_PCA_sm
# Out:
#           PC-1      PC-2      PC-3      PC-4      PC-5      PC-6      PC-7  \
# 0     3.932537 -1.322091 -0.240113 -1.340343  1.677217  0.948754 -2.060909
# 1     1.431637  0.881270 -1.605068  1.663390 -0.258993  0.201300 -0.584506
# 2    -1.578540  2.367014  0.329074 -0.503068  0.608668  0.442717 -1.813800
# 3    -1.830353  2.192943 -0.262375 -0.339395  0.510873  0.960734 -1.077786
# 4     0.186866  2.184660 -0.887924  0.079598  0.961732  0.954327 -1.213300
# ...        ...       ...       ...       ...       ...       ...       ...
# 7623 -0.428186 -2.183831 -2.092568 -0.432741 -1.189728 -1.593554  1.447652
# 7624  0.186531  2.743925  1.896993 -1.312452 -0.239938 -0.869858 -0.969270
# 7625 -0.000550  1.165653  4.300701  2.616107  3.799156 -2.811904  2.766492
# 7626  1.411068 -0.269701  0.825928  2.251350 -0.264224 -0.301312 -0.405270
# 7627 -1.131598  1.496805  0.688986 -0.159219 -1.380281 -1.393729  0.237078
#
#           PC-8      PC-9     PC-10     PC-11     PC-12     PC-13     PC-14  \
# 0     2.458533  0.451262 -0.458314 -0.172944 -1.126805  0.207981 -0.226180
# 1     1.696005  0.484038 -0.587244  1.423945  0.240195 -1.128032 -0.552725
# 2     0.515656  0.506188  0.888219  1.645099 -0.745291  1.064217 -0.495884
# 3    -1.114476  1.724531 -0.856323  1.106687 -0.265893  1.849334 -1.809167
# 4    -0.287560 -0.925762 -1.235411  1.915785 -0.577248 -1.140029 -0.524100
# ...        ...       ...       ...       ...       ...       ...       ...
# 7623  1.218589 -0.495626  0.486662  0.380492  0.096499 -0.166530 -0.468661
# 7624  0.559921 -1.654832 -1.649643  0.011227  0.730586 -0.225682 -0.318516
# 7625  1.267611  0.006087  0.231341 -0.920462  1.258848 -0.149352  1.506556
# 7626 -1.470408 -0.269199 -1.040753  2.180760  2.843262 -0.821169  0.609019
# 7627 -1.124748 -0.532655  0.596582 -1.691270  0.610647  0.066551  1.272512
#
#          PC-15
# 0    -0.841873
# 1     0.179301
# 2     0.907836
# 3    -0.103388
# 4     0.429691
# ...        ...
# 7623  0.833269
# 7624  1.519289
# 7625 -0.454781
# 7626 -1.956845
# 7627 -0.873087
#
# [7628 rows x 15 columns]

# %%
X_test_PCA_sm #原本五萬多筆資料的1/5，沒有經過特徵增強（訓練集不該被看過），標sm只是在此方便辨識
# Out:
#           PC-1      PC-2      PC-3      PC-4      PC-5      PC-6      PC-7  \
# 0    -1.269782  2.893077 -0.182699  0.161363  0.745440  0.620151 -1.698673
# 1     2.217897 -0.722385  1.203529  0.632773  1.262164  0.732580 -2.257904
# 2    -4.580510 -2.598775  0.804134 -0.341555 -0.373209  4.021853  1.645926
# 3    -3.413094 -2.539045  0.192212 -0.970490 -0.437449 -1.004760  0.486409
# 4     2.810438  0.515206 -0.699359  4.048488  3.991817 -1.350898  4.017996
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995 -2.005006 -0.806888 -2.076745  0.874090  0.214105 -0.083051 -0.250604
# 1996 -0.399749  0.336223  2.284988  1.954412 -1.339797 -1.563989 -0.869898
# 1997 -0.331846  0.853158  1.974110 -0.049839 -0.909832 -0.661471 -0.209417
# 1998 -2.547640  1.396868 -0.039374 -0.782348  0.415158  0.727915 -1.185969
# 1999 -1.094282 -1.055815 -1.891500  1.244694  0.216358 -0.085955 -0.657263
#
#           PC-8      PC-9     PC-10     PC-11     PC-12     PC-13     PC-14  \
# 0     0.494890 -1.335320 -1.475367 -0.189590  0.343780 -0.276569  1.031649
# 1     0.106000 -0.013707  0.850276  0.579370 -0.356027 -0.977843 -0.003172
# 2    -0.057094  1.431456 -0.571124 -0.819974  1.119305 -0.723378  0.047178
# 3    -0.689528  0.639523  0.272878 -0.863535 -0.262274 -1.073756 -1.977487
# 4     0.383183  1.533226 -0.033889 -0.445802 -0.807272  0.044537  0.418507
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995 -0.739128 -1.745207  2.410473 -2.521053  1.040216  0.510288 -0.409421
# 1996  0.810525 -0.962981  2.218892 -1.132655  0.804041 -0.698792 -0.495082
# 1997 -1.144032  1.190734 -0.385297  0.736219 -1.940916  1.641602 -1.886250
# 1998 -0.881394  2.490228 -0.488640 -0.929166 -1.100661 -1.254455 -1.609284
# 1999  2.758249 -1.624506 -1.113391 -1.332726 -0.109966  0.888485 -0.205068
#
#          PC-15
# 0    -0.625000
# 1     1.154404
# 2     0.053412
# 3     0.512953
# 4     0.072291
# ...        ...
# 1995  0.326516
# 1996  0.658169
# 1997 -0.592171
# 1998 -0.031016
# 1999  0.701156
#
# [2000 rows x 15 columns]

# %%
model = DecisionTreeClassifier(splitter='random')
fit_result(model, X_train_PCA_sm, y_train_sm, X_test_PCA_sm, y_test)
# Out:
# 對於主要目標 標籤為1的預測
# Precision：0.568561872909699,             Recall：0.8056872037914692,
#         Accuracy：0.745,        AUC：0.761292760637505,        f1-score：0.6666666666666666
# [[980 387]
#  [123 510]]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.72      0.79      1367
#          1.0       0.57      0.81      0.67       633
#
#     accuracy                           0.74      2000
#    macro avg       0.73      0.76      0.73      2000
# weighted avg       0.79      0.74      0.75      2000
# The TP rate is: 0.72
# The TN rate is: 0.81
# The FN rate is: 0.28
# The FP rate is: 0.19

# %% [markdown]
# <div></div>

# %%
from yellowbrick.features import RadViz


visualizer = RadViz(classes=df['OUTCOME'].unique(),
                    features=list(df.columns[:-1]), size=(720, 720))
visualizer.fit(df.iloc[:,:-1].values, df['OUTCOME'].values)
visualizer.transform(df[:-1].values)
visualizer.poof()
# Out:
# <AxesSubplot: title={'center': 'RadViz for 15 Features'}>

# %% [markdown]
# <div></div>

# %% [markdown]
# <div style="background-color:#D9D9D9;"><font size="20"><b>Model Training</b></font></div>

# %%
# conda list scikit

# %%
# conda install -c conda-forge lazypredict

# %%
# from lazypredict.Supervised import LazyClassifier

# clf = LazyClassifier(predictions=True)
# models, predictions = clf.fit(X_train_final, X_test_final, y_train_final, y_test_final)
# models

# %%
# model = DecisionTreeClassifier(splitter='random')
# fit_result(model, X_train_final, y_train_final, X_test_final, y_test_final)

# %% [markdown]
# ### 使用CrossCV測試各種模型參數
# <font size="3">⚠️⚠️⚠️ 使用時長很大，小心執行。 ⚠️⚠️⚠️</font>

# %%
#crossCV挑參數
#https://blog.csdn.net/weixin_41712499/article/details/82882542
#https://ithelp.ithome.com.tw/articles/10267379?sc=iThomeR
# n_estimators: 森林中樹木的數量，預設=100。
# max_features: 劃分時考慮的最大特徵數，預設auto。
# criterion: 亂度的評估標準，gini/entropy。預設為gini。
# max_depth: 樹的最大深度。
# splitter: 特徵劃分點選擇標準，best/random。預設為best。
# random_state: 亂數種子，確保每次訓練結果都一樣，splitter=random 才有用。
# min_samples_split: 至少有多少資料才能再分
# min_samples_leaf: 分完至少有多少資料才能分
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RandomizedSearchCV

model = RandomForestClassifier(n_estimators=100, random_state= 42)

n_estimators = [int(x) for x in np.linspace(start=100, stop=2000, num=10)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(5,15, num=8)]
max_depth.append(None)
min_samples_split = [2, 3, 7, 13, 20, 50, 100]
min_samples_leaf = [5, 10, 20, 40, 80]
bootstrap = [True, False]

random_grid = {'n_estimators': n_estimators, 'max_features': max_features,
               'max_depth': max_depth, 'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf, 'bootstrap': bootstrap}
random_grid
# Out:
# {'n_estimators': [100, 311, 522, 733, 944, 1155, 1366, 1577, 1788, 2000],
#  'max_features': ['auto', 'sqrt'],
#  'max_depth': [5, 6, 7, 9, 10, 12, 13, 15, None],
#  'min_samples_split': [2, 3, 7, 13, 20, 50, 100],
#  'min_samples_leaf': [5, 10, 20, 40, 80],
#  'bootstrap': [True, False]}

# %%
rdforest = RandomForestClassifier(random_state=42)
rf_random = RandomizedSearchCV(estimator = rdforest, 
                               param_distributions=random_grid,
                               n_iter=5, cv=3, verbose=3, 
                               scoring='f1_macro', random_state=42)#, n_jobs=-1

# %% [markdown]
# ### Before oversampling

# %%
X_train_PCA, y_train, X_test_PCA, y_test

rf_random.fit(X_train_PCA, y_train)
param =  rf_random.best_params_
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV 1/3] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=40, min_samples_split=100, n_estimators=100;, score=0.773 total time=   1.0s
# [CV 2/3] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=40, min_samples_split=100, n_estimators=100;, score=0.775 total time=   1.0s
# [CV 3/3] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=40, min_samples_split=100, n_estimators=100;, score=0.764 total time=   1.2s
# [CV 1/3] END bootstrap=True, max_depth=6, max_features=auto, min_samples_leaf=20, min_samples_split=7, n_estimators=100;, score=0.777 total time=   0.7s
# [CV 2/3] END bootstrap=True, max_depth=6, max_features=auto, min_samples_leaf=20, min_samples_split=7, n_estimators=100;, score=0.774 total time=   0.6s
# [CV 3/3] END bootstrap=True, max_depth=6, max_features=auto, min_samples_leaf=20, min_samples_split=7, n_estimators=100;, score=0.767 total time=   0.6s
# [CV 1/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=100;, score=0.785 total time=   0.8s
# [CV 2/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=100;, score=0.788 total time=   0.8s
# [CV 3/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=100;, score=0.779 total time=   0.8s
# [CV 1/3] END bootstrap=True, max_depth=15, max_features=auto, min_samples_leaf=80, min_samples_split=3, n_estimators=311;, score=0.768 total time=   1.9s
# [CV 2/3] END bootstrap=True, max_depth=15, max_features=auto, min_samples_leaf=80, min_samples_split=3, n_estimators=311;, score=0.771 total time=   1.9s
# [CV 3/3] END bootstrap=True, max_depth=15, max_features=auto, min_samples_leaf=80, min_samples_split=3, n_estimators=311;, score=0.767 total time=   1.9s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=944;, score=0.787 total time=  12.7s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=944;, score=0.788 total time=  11.9s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=944;, score=0.783 total time=  11.5s

# %%
# param = {'n_estimators': 944,
#  'min_samples_split': 3,
#  'min_samples_leaf': 10,
#  'max_features': 'auto',
#  'max_depth': 15,
#  'bootstrap': False}
rdforest_b4sm = RandomForestClassifier(param, random_state=42)
fit_result(model, X_train_PCA, y_train, X_test_PCA, y_test)
# Out:
# 對於主要目標 標籤為1的預測
# Precision：0.7543186180422264,             Recall：0.6208530805687204,
#         Accuracy：0.816,        AUC：0.8787956006568738,        f1-score：0.681109185441941
# [[1239  128]
#  [ 240  393]]
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.91      0.87      1367
#          1.0       0.75      0.62      0.68       633
#
#     accuracy                           0.82      2000
#    macro avg       0.80      0.76      0.78      2000
# weighted avg       0.81      0.82      0.81      2000
# The TP rate is: 0.91
# The TN rate is: 0.62
# The FN rate is: 0.094
# The FP rate is: 0.38

# %% [markdown]
# ### After oversampling

# %%
rf_random.fit(X_train_PCA_sm, y_train_sm)
rf_random.best_params_
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV 1/3] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=40, min_samples_split=100, n_estimators=100;, score=0.873 total time=   0.9s
# [CV 2/3] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=40, min_samples_split=100, n_estimators=100;, score=0.877 total time=   0.8s
# [CV 3/3] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=40, min_samples_split=100, n_estimators=100;, score=0.698 total time=   0.8s
# [CV 1/3] END bootstrap=True, max_depth=6, max_features=auto, min_samples_leaf=20, min_samples_split=7, n_estimators=100;, score=0.872 total time=   0.6s
# [CV 2/3] END bootstrap=True, max_depth=6, max_features=auto, min_samples_leaf=20, min_samples_split=7, n_estimators=100;, score=0.877 total time=   0.6s
# [CV 3/3] END bootstrap=True, max_depth=6, max_features=auto, min_samples_leaf=20, min_samples_split=7, n_estimators=100;, score=0.710 total time=   0.6s
# [CV 1/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=100;, score=0.902 total time=   0.7s
# [CV 2/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=100;, score=0.906 total time=   0.8s
# [CV 3/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=100;, score=0.781 total time=   0.7s
# [CV 1/3] END bootstrap=True, max_depth=15, max_features=auto, min_samples_leaf=80, min_samples_split=3, n_estimators=311;, score=0.881 total time=   1.8s
# [CV 2/3] END bootstrap=True, max_depth=15, max_features=auto, min_samples_leaf=80, min_samples_split=3, n_estimators=311;, score=0.882 total time=   1.8s
# [CV 3/3] END bootstrap=True, max_depth=15, max_features=auto, min_samples_leaf=80, min_samples_split=3, n_estimators=311;, score=0.708 total time=   2.0s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=944;, score=0.903 total time=  12.6s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=944;, score=0.912 total time=  11.4s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=944;, score=0.775 total time=  10.8s
# {'n_estimators': 944,
#  'min_samples_split': 100,
#  'min_samples_leaf': 5,
#  'max_features': 'auto',
#  'max_depth': None,
#  'bootstrap': False}

# %%
rdforest_sm = RandomForestClassifier(rf_random.best_params_, random_state=42)
fit_result(model, X_train_PCA_sm, y_train_sm, X_test_PCA_sm, y_test)
# Out:
# 對於主要目標 標籤為1的預測
# Precision：0.6071829405162739,             Recall：0.8546603475513428,
#         Accuracy：0.779,        AUC：0.8801800739849603,        f1-score：0.70997375328084
# [[1017  350]
#  [  92  541]]
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.74      0.82      1367
#          1.0       0.61      0.85      0.71       633
#
#     accuracy                           0.78      2000
#    macro avg       0.76      0.80      0.77      2000
# weighted avg       0.82      0.78      0.79      2000
# The TP rate is: 0.74
# The TN rate is: 0.85
# The FN rate is: 0.26
# The FP rate is: 0.15
